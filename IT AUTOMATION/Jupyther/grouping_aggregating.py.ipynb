# %%
#Python Pandas Tutorial (Part 8): Grouping and Aggregating - Analyzing and Exploring Your Data
#https://www.youtube.com/watch?v=txMdrV1Ut64&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS&index=8
import pandas as pd


pd_schema = pd.read_csv(r'C:\Users\srini\OneDrive\Documents\stackOverFlow\survey_results_schema.csv')
pd_public = pd.read_csv(r'C:\Users\srini\OneDrive\Documents\stackOverFlow\survey_results_public.csv')

pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)
df_pub = pd.DataFrame(pd_public)
df_schema = pd.DataFrame(pd_schema)

# %%
df_pub.head(10)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
# 5           6  I am not primarily a developer, but I write co...
# 6           7                        I code primarily as a hobby
# 7           8                     I am a developer by profession
# 8           9                     I am a developer by profession
# 9          10                     I am a developer by profession
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# ...

# %%
df_pub['ConvertedCompYearly'].head(20)
# Out:
# 0          NaN
# 1          NaN
# 2      40205.0
# 3     215232.0
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8      49056.0
# 9          NaN
# 10     60307.0
# 11    194400.0
# 12     65000.0
# 13         NaN
# 14    110000.0
# 15         NaN
# 16     19224.0
# 17    202623.0
# 18     51192.0
# 19         NaN
# Name: ConvertedCompYearly, dtype: float64

# %%
df_pub['ConvertedCompYearly'].median()
# Out:
# 67845.0

# %%
df_pub.median()
# Out:
# C:\Users\srini\AppData\Local\Temp\ipykernel_16752\3515642016.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_pub.median()
# ResponseId                   36634.5
# CompTotal                    77500.0
# VCHostingPersonal use            NaN
# VCHostingProfessional use        NaN
# WorkExp                          8.0
# ConvertedCompYearly          67845.0
# dtype: float64

# %%
df_pub.describe()
# Out:
#          ResponseId     CompTotal  VCHostingPersonal use  \
# count  73268.000000  3.842200e+04                    0.0
# mean   36634.500000  2.342434e+52                    NaN
# std    21150.794099  4.591478e+54                    NaN
# min        1.000000  0.000000e+00                    NaN
# 25%    18317.750000  3.000000e+04                    NaN
# 50%    36634.500000  7.750000e+04                    NaN
# 75%    54951.250000  1.540000e+05                    NaN
# max    73268.000000  9.000000e+56                    NaN
#
#        VCHostingProfessional use       WorkExp  ConvertedCompYearly
# count                        0.0  36769.000000         3.807100e+04
# mean                         NaN     10.242378         1.707613e+05
# std                          NaN      8.706850         7.814132e+05
# min                          NaN      0.000000         1.000000e+00
# 25%                          NaN      4.000000         3.583200e+04
# ...

# %%
df_pub['ConvertedCompYearly'].count()
# Out:
# 38071

# %%
df_pub['SOAccount']
# Out:
# 0                            NaN
# 1                            Yes
# 2                            Yes
# 3                            Yes
# 4                            Yes
#                   ...
# 73263                        Yes
# 73264    Not sure/can't remember
# 73265                        Yes
# 73266                        Yes
# 73267                        Yes
# Name: SOAccount, Length: 73268, dtype: object

# %%
df_pub['SOAccount'].value_counts()
# Out:
# Yes                        58519
# No                          8951
# Not sure/can't remember     4102
# Name: SOAccount, dtype: int64

# %%
df_pub['LearnCodeCoursesCert']
# Out:
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#                        ...
# 73263                               Udemy
# 73264              Coursera;Udemy;Udacity
# 73265    Udemy;Codecademy;Pluralsight;edX
# 73266                                 NaN
# 73267                   Udemy;Pluralsight
# Name: LearnCodeCoursesCert, Length: 73268, dtype: object

# %%
df_pub['LearnCodeCoursesCert'].value_counts(normalize=True)
# Out:
# Udemy                                     0.192011
# Other                                     0.088264
# Coursera;Udemy                            0.064412
# Udemy;Codecademy                          0.050087
# Udemy;Pluralsight                         0.047705
#                                             ...
# Udemy;Codecademy;edX;Udacity;Skillsoft    0.000034
# Coursera;Other;Skillsoft                  0.000034
# Codecademy;edX;Udacity;Skillsoft          0.000034
# Pluralsight;edX;Udacity;Other             0.000034
# Coursera;Pluralsight;Other;Skillsoft      0.000034
# Name: LearnCodeCoursesCert, Length: 206, dtype: float64

# %%
df_pub['LearnCodeCoursesCert']
# Out:
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#                        ...
# 73263                               Udemy
# 73264              Coursera;Udemy;Udacity
# 73265    Udemy;Codecademy;Pluralsight;edX
# 73266                                 NaN
# 73267                   Udemy;Pluralsight
# Name: LearnCodeCoursesCert, Length: 73268, dtype: object

# %%
df_pub['Country'].value_counts()
# Out:
# United States of America                                13543
# India                                                    6639
# Germany                                                  5395
# United Kingdom of Great Britain and Northern Ireland     4190
# Canada                                                   2490
#                                                         ...
# Monaco                                                      1
# Djibouti                                                    1
# Seychelles                                                  1
# Solomon Islands                                             1
# Saint Kitts and Nevis                                       1
# Name: Country, Length: 180, dtype: int64

# %%
df_pub.groupby(['Country'])

# %%
country_grp = df_pub.groupby(['Country'])
country_grp.get_group('India')
# Out:
#        ResponseId                                         MainBranch  \
# 6               7                        I code primarily as a hobby
# 7               8                     I am a developer by profession
# 65             66                     I am a developer by profession
# 140           141                     I am a developer by profession
# 151           152                     I am a developer by profession
# ...           ...                                                ...
# 73184       73185                     I am a developer by profession
# 73193       73194  I used to be a developer by profession, but no...
# 73255       73256                     I am a developer by profession
# 73257       73258                              I am learning to code
# 73258       73259                     I am a developer by profession
#
#                                Employment  \
# 6                      Student, part-time
# 7      Not employed, but looking for work
# ...

# %%
#alternate method
filt = df_pub['Country'] =='India'
df_pub.loc[filt]
# Out:
#        ResponseId                                         MainBranch  \
# 6               7                        I code primarily as a hobby
# 7               8                     I am a developer by profession
# 65             66                     I am a developer by profession
# 140           141                     I am a developer by profession
# 151           152                     I am a developer by profession
# ...           ...                                                ...
# 73184       73185                     I am a developer by profession
# 73193       73194  I used to be a developer by profession, but no...
# 73255       73256                     I am a developer by profession
# 73257       73258                              I am learning to code
# 73258       73259                     I am a developer by profession
#
#                                Employment  \
# 6                      Student, part-time
# 7      Not employed, but looking for work
# ...

# %%
#https://www.youtube.com/watch?v=txMdrV1Ut64&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS&index=11&ab_channel=CoreySchafer
#18.16
