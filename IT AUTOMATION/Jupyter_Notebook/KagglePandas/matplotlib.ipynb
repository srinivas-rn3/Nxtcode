# %%
import matplotlib.pyplot as plt

x = [10,20,30,40]
y = [20,30,40,50]

plt.plot(x,y)
plt.title("my plot")

plt.ylabel("y-Axis")
plt.xlabel("x-Axis")
plt.show()

# %%
#https://www.geeksforgeeks.org/python-introduction-matplotlib/
