# %% [markdown]
# https://www.dataquest.io/blog/how-much-spent-amazon-data-analysis/ --- Issue wiht smaple data
# https://www.dataquest.io/blog/how-to-analyze-survey-data-python-beginner/ -- Present working on

# %% [markdown]
# ***How to Analyze Survey Data with Python for Beginners***

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\srini\OneDrive\Documents\stackOverFlow\survey_results_public.csv")
df.head(10)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
# 5           6  I am not primarily a developer, but I write co...
# 6           7                        I code primarily as a hobby
# 7           8                     I am a developer by profession
# 8           9                     I am a developer by profession
# 9          10                     I am a developer by profession
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# ...

# %%
df.shape
# Out:
# (73268, 79)

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
df['Age'].value_counts()
# Out:
# 25-34 years old       28112
# 18-24 years old       16646
# 35-44 years old       13988
# 45-54 years old        5281
# Under 18 years old     3866
# 55-64 years old        1978
# 65 years or older       554
# Prefer not to say       521
# Name: Age, dtype: int64

# %%
df['Employment'].value_counts()
# Out:
# Employed, full-time                                                                                                                    42962
# Student, full-time                                                                                                                      6756
# Independent contractor, freelancer, or self-employed                                                                                    4978
# Employed, full-time;Independent contractor, freelancer, or self-employed                                                                3486
# Not employed, but looking for work                                                                                                      1831
#                                                                                                                                        ...
# Student, part-time;Independent contractor, freelancer, or self-employed;Retired                                                            1
# ...

# %%
df['Employment'].value_counts(normalize=True)
# Out:
# Employed, full-time                                                                                                                    0.599116
# Student, full-time                                                                                                                     0.094214
# Independent contractor, freelancer, or self-employed                                                                                   0.069419
# Employed, full-time;Independent contractor, freelancer, or self-employed                                                               0.048613
# Not employed, but looking for work                                                                                                     0.025534
#                                                                                                                                          ...
# ...

# %%
df['Age'].value_counts(normalize=True)
# Out:
# 25-34 years old       0.396245
# 18-24 years old       0.234629
# 35-44 years old       0.197164
# 45-54 years old       0.074437
# Under 18 years old    0.054492
# 55-64 years old       0.027880
# 65 years or older     0.007809
# Prefer not to say     0.007344
# Name: Age, dtype: float64

# %%
df['Sexuality'].value_counts(normalize=True)
# Out:
# Straight / Heterosexual                                                           0.829835
# Prefer not to say                                                                 0.065350
# Bisexual                                                                          0.040562
# Gay or Lesbian                                                                    0.020762
# Prefer to self-describe:                                                          0.016210
# Queer                                                                             0.005919
# Bisexual;Straight / Heterosexual                                                  0.005318
# Bisexual;Queer                                                                    0.004236
# Straight / Heterosexual;Prefer to self-describe:                                  0.002539
# Gay or Lesbian;Queer                                                              0.002253
# ...

# %%
# %matplotlib inline

# %%
df['Age'].value_counts().plot(kind='bar',color='#61d199')
# Out:
# <AxesSubplot: >

# %%
bool_gen = df[df['Gender'] == 'Woman']
bool_gen.head(5)
# Out:
#     ResponseId                      MainBranch  \
# 8            9  I am a developer by profession
# 9           10  I am a developer by profession
# 13          14  I am a developer by profession
# 17          18  I am a developer by profession
# 46          47     I code primarily as a hobby
#
#                                            Employment  \
# 8                                 Employed, full-time
# 9   Independent contractor, freelancer, or self-em...
# 13                                Employed, part-time
# 17                                Employed, full-time
# 46                                 Student, full-time
#
#                               RemoteWork  \
# 8   Hybrid (some remote, some in-person)
# 9                           Fully remote
# 13                          Fully remote
# 17                          Fully remote
# 46                                   NaN
#
#                                      CodingActivities  \
# ...

# %%
bool_gen.shape
# Out:
# (3399, 79)

# %%
bool_gen['Age'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
bool_gen['Sexuality'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >
