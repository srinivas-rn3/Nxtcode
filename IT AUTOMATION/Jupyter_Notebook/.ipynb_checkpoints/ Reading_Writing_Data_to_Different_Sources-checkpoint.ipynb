# %% [markdown]
# #https://www.youtube.com/watch?v=N6hyN6BW6ao&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS&index=11&ab_channel=CoreySchafer

# %% [markdown]
# **Python Pandas Tutorial (Part 11): Reading/Writing Data to Different Sources - Excel, JSON, SQL, Etc**

# %%
import pandas as pd

# %%
pd_schema = pd.read_csv(r'C:\Users\srini\OneDrive\Documents\stackOverFlow\survey_results_schema.csv')
pd_public = pd.read_csv(r'C:\Users\srini\OneDrive\Documents\stackOverFlow\survey_results_public.csv')

pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)
df1 = pd.DataFrame(pd_public)
df2 = pd.DataFrame(pd_schema)

# %%
df1.head(5)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# ...

# %%
filt = (df1['Country'] == 'India')
i_df = df1.loc[filt]
i_df.head(10)
# Out:
#      ResponseId                      MainBranch  \
# 6             7     I code primarily as a hobby
# 7             8  I am a developer by profession
# 65           66  I am a developer by profession
# 140         141  I am a developer by profession
# 151         152  I am a developer by profession
# 162         163           I am learning to code
# 169         170  I am a developer by profession
# 179         180  I am a developer by profession
# 196         197  I am a developer by profession
# 291         292  I am a developer by profession
#
#                                             Employment  \
# 6                                   Student, part-time
# 7                   Not employed, but looking for work
# 65                                 Employed, full-time
# 140                                Employed, full-time
# 151                                Employed, full-time
# 162                                Employed, full-time
# ...

# %%
i_df.to_csv(r'C:\Users\srini\OneDrive\Documents\stackOverFlow\Modified_Data_India.csv',index=False)

# %%
i_df.to_csv(r'C:\Users\srini\OneDrive\Documents\stackOverFlow\Modified_Data_India.tsv',sep = '\t',index=False)

# %%
i_df.to_excel(r'C:\Users\srini\OneDrive\Documents\stackOverFlow\Modified_Data_India.xlsx',index=False)

# %%
test = pd.read_excel(r'C:\Users\srini\OneDrive\Documents\stackOverFlow\Modified_Data_India.xlsx',index_col='ResponseId')

# %%
test.head()
# Out:
#                                 MainBranch  \
# ResponseId
# 7              I code primarily as a hobby
# 8           I am a developer by profession
# 66          I am a developer by profession
# 141         I am a developer by profession
# 152         I am a developer by profession
#
#                                     Employment  \
# ResponseId
# 7                           Student, part-time
# 8           Not employed, but looking for work
# 66                         Employed, full-time
# 141                        Employed, full-time
# 152                        Employed, full-time
#
#                                       RemoteWork  \
# ResponseId
# 7                                            NaN
# 8                                            NaN
# 66          Hybrid (some remote, some in-person)
# 141         Hybrid (some remote, some in-person)
# 152                               Full in-person
#
#                          CodingActivities  \
# ResponseId
# ...

# %%
#12.23

# %%
i_df.to_json(r'C:\Users\srini\OneDrive\Documents\stackOverFlow\Modified_Data_India.json')

# %%
 i_df.to_json(r'C:\Users\srini\OneDrive\Documents\stackOverFlow\Modified_Data_India.json',orient='records',lines=False)

# %%
test1 = pd.read_json(r'C:\Users\srini\OneDrive\Documents\stackOverFlow\Modified_Data_India.json',orient='records',lines=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 test1 = pd.read_json(r'C:\Users\srini\OneDrive\Documents\stackOverFlow\Modified_Data_India.json',orient='records',lines=False)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
# ...

# %%
test1.head(5)
# Out:
#    ResponseId                      MainBranch  \
# 0           7     I code primarily as a hobby
# 1           8  I am a developer by profession
# 2          66  I am a developer by profession
# 3         141  I am a developer by profession
# 4         152  I am a developer by profession
#
#                            Employment                            RemoteWork  \
# 0                  Student, part-time                                  None
# 1  Not employed, but looking for work                                  None
# 2                 Employed, full-time  Hybrid (some remote, some in-person)
# 3                 Employed, full-time  Hybrid (some remote, some in-person)
# 4                 Employed, full-time                        Full in-person
#
#                 CodingActivities  \
# 0                           None
# 1                           None
# 2  Hobby;Other (please specify):
# 3   I don’t code outside of work
# 4                          Hobby
#
# ...

# %%
#24.56
